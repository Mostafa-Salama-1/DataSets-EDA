# %% [markdown]
# the link of the data from Kaggle (https://www.kaggle.com/datasets/priyamchoksi/spotify-dataset-114k-songs/data)

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
main_df=pd.read_csv("dataset.csv")
main_df
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %% [markdown]
# # EDA

# %%
df=main_df.copy()
df
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
df = df.drop(["Unnamed: 0","track_id","track_name","artists","album_name"], axis = 1) 
df
# Out:
#         popularity  duration_ms  explicit  danceability  energy  key  \
# 0               73       230666     False         0.676  0.4610    1
# 1               55       149610     False         0.420  0.1660    1
# 2               57       210826     False         0.438  0.3590    0
# 3               71       201933     False         0.266  0.0596    0
# 4               82       198853     False         0.618  0.4430    2
# ...            ...          ...       ...           ...     ...  ...
# 113995          21       384999     False         0.172  0.2350    5
# 113996          22       385000     False         0.174  0.1170    0
# 113997          22       271466     False         0.629  0.3290    0
# 113998          41       283893     False         0.587  0.5060    7
# 113999          22       241826     False         0.526  0.4870    1
#
#         loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   popularity        114000 non-null  int64
#  1   duration_ms       114000 non-null  int64
#  2   explicit          114000 non-null  bool
#  3   danceability      114000 non-null  float64
#  4   energy            114000 non-null  float64
#  5   key               114000 non-null  int64
#  6   loudness          114000 non-null  float64
#  7   mode              114000 non-null  int64
#  8   speechiness       114000 non-null  float64
#  9   acousticness      114000 non-null  float64
#  10  instrumentalness  114000 non-null  float64
#  11  liveness          114000 non-null  float64
#  12  valence           114000 non-null  float64
#  13  tempo             114000 non-null  float64
#  14  time_signature    114000 non-null  int64
#  15  track_genre       114000 non-null  object
# ...

# %%
df.describe()
# Out:
#           popularity   duration_ms   danceability         energy  \
# count  114000.000000  1.140000e+05  114000.000000  114000.000000
# mean       33.238535  2.280292e+05       0.566800       0.641383
# std        22.305078  1.072977e+05       0.173542       0.251529
# min         0.000000  0.000000e+00       0.000000       0.000000
# 25%        17.000000  1.740660e+05       0.456000       0.472000
# 50%        35.000000  2.129060e+05       0.580000       0.685000
# 75%        50.000000  2.615060e+05       0.695000       0.854000
# max       100.000000  5.237295e+06       0.985000       1.000000
#
#                  key       loudness           mode    speechiness  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        5.309140      -8.258960       0.637553       0.084652
# std         3.559987       5.029337       0.480709       0.105732
# min         0.000000     -49.531000       0.000000       0.000000
# ...

# %%
df.duration_ms.min()
# Out:
# 0

# %%
df[df.duration_ms==df.duration_ms.min()]
# Out:
#        popularity  duration_ms  explicit  danceability  energy  key  loudness  \
# 65900           0            0     False         0.501   0.583    7     -9.46
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 65900     0       0.0605          0.69           0.00396    0.0747    0.734
#
#          tempo  time_signature track_genre
# 65900  138.391               4       k-pop

# %%
df = df[df['duration_ms'] > 0]

# %%
df.describe()
# Out:
#           popularity   duration_ms   danceability         energy  \
# count  113999.000000  1.139990e+05  113999.000000  113999.000000
# mean       33.238827  2.280312e+05       0.566801       0.641383
# std        22.304959  1.072961e+05       0.173543       0.251530
# min         0.000000  8.586000e+03       0.000000       0.000000
# 25%        17.000000  1.740660e+05       0.456000       0.472000
# 50%        35.000000  2.129060e+05       0.580000       0.685000
# 75%        50.000000  2.615060e+05       0.695000       0.854000
# max       100.000000  5.237295e+06       0.985000       1.000000
#
#                  key       loudness           mode    speechiness  \
# count  113999.000000  113999.000000  113999.000000  113999.000000
# mean        5.309126      -8.258950       0.637558       0.084652
# std         3.559999       5.029357       0.480708       0.105733
# min         0.000000     -49.531000       0.000000       0.000000
# ...

# %%
len(df.track_genre.value_counts().to_list())
# Out:
# 114

# %%
df
# Out:
#         popularity  duration_ms  explicit  danceability  energy  key  \
# 0               73       230666     False         0.676  0.4610    1
# 1               55       149610     False         0.420  0.1660    1
# 2               57       210826     False         0.438  0.3590    0
# 3               71       201933     False         0.266  0.0596    0
# 4               82       198853     False         0.618  0.4430    2
# ...            ...          ...       ...           ...     ...  ...
# 113995          21       384999     False         0.172  0.2350    5
# 113996          22       385000     False         0.174  0.1170    0
# 113997          22       271466     False         0.629  0.3290    0
# 113998          41       283893     False         0.587  0.5060    7
# 113999          22       241826     False         0.526  0.4870    1
#
#         loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
plt.boxplot(df.duration_ms)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29d680dee90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x29d680ec450>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x29d6809cf50>],
#  'medians': [<matplotlib.lines.Line2D at 0x29d680ed950>],
#  'fliers': [<matplotlib.lines.Line2D at 0x29d680ee250>],
#  'means': []}

# %%
q1=df.duration_ms.quantile(0.25)
q2=df.duration_ms.quantile(0.75)
IQR=q2-q1
upper=q2+(1.5*IQR)
lower=q1-(1.5*IQR)
outliears=df.loc[((df.duration_ms>upper)|(df.duration_ms< lower))]
len(outliears)
# Out:
# 5616

# %%
new_df=df.copy()
new_df.loc[((df.duration_ms>upper),"duration_ms")]=upper
new_df.loc[((df.duration_ms<lower),"duration_ms")]=lower
len(new_df)
# Out:
# 113999

# %%
plt.boxplot(new_df.duration_ms)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29d6a0e5010>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x29d6a0b3ed0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x29d6a0e4490>],
#  'medians': [<matplotlib.lines.Line2D at 0x29d6a0e75d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x29d6a0f40d0>],
#  'means': []}

# %%
plt.boxplot(new_df.loudness)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29d6a153190>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x29d6a160950>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x29d6a152750>],
#  'medians': [<matplotlib.lines.Line2D at 0x29d6a161f10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x29d6a162a50>],
#  'means': []}

# %%
q1=new_df.loudness.quantile(0.25)
q2=new_df.loudness.quantile(0.75)
IQR=q2-q1
upper=q2+(1.5*IQR)
lower=q1-(1.5*IQR)
outliears=df.loc[((new_df.loudness>upper)|(new_df.loudness< lower))]
len(outliears) #6173
new_df.loc[((df.loudness>upper),"loudness")]=upper
new_df.loc[((df.loudness<lower),"loudness")]=lower
len(new_df) #113999
plt.boxplot(new_df.loudness)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29d6d208590>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x29d6d209b50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x29d6d1fbb90>],
#  'medians': [<matplotlib.lines.Line2D at 0x29d6d20b290>],
#  'fliers': [<matplotlib.lines.Line2D at 0x29d6d20be10>],
#  'means': []}

# %%
plt.boxplot(new_df.tempo)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29d6d2781d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x29d6d279550>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x29d6d26b850>],
#  'medians': [<matplotlib.lines.Line2D at 0x29d6d27a710>],
#  'fliers': [<matplotlib.lines.Line2D at 0x29d6d27b090>],
#  'means': []}

# %%
q1=new_df.tempo.quantile(0.25)
q2=new_df.tempo.quantile(0.75)
IQR=q2-q1
upper=q2+(1.5*IQR)
lower=q1-(1.5*IQR)
outliears=df.loc[((new_df.tempo>upper)|(new_df.tempo< lower))]
len(outliears) #617
new_df.loc[((df.tempo>upper),"tempo")]=upper
new_df.loc[((df.tempo<lower),"tempo")]=lower
len(new_df) #113999
plt.boxplot(new_df.tempo)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29d671a3f90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x29d671a9510>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x29d671a36d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x29d671aaad0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x29d671ab5d0>],
#  'means': []}

# %%
new_df.columns
# Out:
# Index(['popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %%
new_df.duplicated().sum()
# Out:
# 7093

# %%
new_df = new_df.drop_duplicates()
new_df.shape
# Out:
# (106906, 16)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# Fit the encoder and transform the 'track_genre' column
new_df['track_genre'] = label_encoder.fit_transform(new_df['track_genre'])
new_df
# Out:
#         popularity  duration_ms  explicit  danceability  energy  key  \
# 0               73       230666     False         0.676  0.4610    1
# 1               55       149610     False         0.420  0.1660    1
# 2               57       210826     False         0.438  0.3590    0
# 3               71       201933     False         0.266  0.0596    0
# 4               82       198853     False         0.618  0.4430    2
# ...            ...          ...       ...           ...     ...  ...
# 113995          21       384999     False         0.172  0.2350    5
# 113996          22       385000     False         0.174  0.1170    0
# 113997          22       271466     False         0.629  0.3290    0
# 113998          41       283893     False         0.587  0.5060    7
# 113999          22       241826     False         0.526  0.4870    1
#
#         loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
y=new_df['track_genre'].copy()
new_df=new_df.drop(['track_genre'],axis=1)

# %%
from sklearn.preprocessing import StandardScaler

# Initialize the scaler
scaler = StandardScaler()

# Fit the scaler on the data and transform it
df_scaled = scaler.fit_transform(new_df)

# Convert back to a DataFrame if needed
df_scaled = pd.DataFrame(df_scaled, columns=new_df.columns)
new_df=df_scaled

# %%
new_df
# Out:
#         popularity  duration_ms  explicit  danceability    energy       key  \
# 0         1.764188     0.087548 -0.304862      0.638577 -0.720545 -1.210305
# 1         0.920562    -1.009422 -0.304862     -0.835008 -1.889265 -1.210305
# 2         1.014298    -0.180957 -0.304862     -0.731396 -1.124645 -1.491541
# 3         1.670452    -0.301310 -0.304862     -1.721461 -2.310797 -1.491541
# 4         2.186001    -0.342993 -0.304862      0.304718 -0.791857 -0.929070
# ...            ...          ...       ...           ...       ...       ...
# 106901   -0.672954     2.176210 -0.304862     -2.262543 -1.615904 -0.085363
# 106902   -0.626085     2.176224 -0.304862     -2.251031 -2.083392 -1.491541
# 106903   -0.626085     0.639714 -0.304862      0.368036 -1.243498 -1.491541
# 106904    0.264409     0.807894 -0.304862      0.126276 -0.542266  0.477108
# 106905   -0.626085     0.238581 -0.304862     -0.224851 -0.617540 -1.210305
#
# ...

# %%
fig, axs = plt.subplots(4, 2, figsize=(12, 16))

# List of columns you want to plot
columns_to_plot = ['popularity', 'duration_ms', 'danceability', 'energy', 'key', 'mode', 'speechiness', 'acousticness']

# Iterate over the axes and columns to create each plot
for i, ax in enumerate(axs.flat):
    # Plot a histogram for each column in the grid
    ax.hist(new_df[columns_to_plot[i]], bins=30, edgecolor='black')
    ax.set_title(f'Histogram of {columns_to_plot[i]}')
    ax.set_xlabel(columns_to_plot[i])
    ax.set_ylabel('Frequency')

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
fig, axs = plt.subplots(4, 2, figsize=(12, 16))

# List of columns you want to plot
columns_to_plot = ['instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']

# Iterate over the axes and columns to create each plot
for i, ax in enumerate(axs.flat):
    # Plot a histogram for each column in the grid
    ax.hist(new_df[columns_to_plot[i]], bins=30, edgecolor='black')
    ax.set_title(f'Histogram of {columns_to_plot[i]}')
    ax.set_xlabel(columns_to_plot[i])
    ax.set_ylabel('Frequency')

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[29], line 9
#       6 # Iterate over the axes and columns to create each plot
#       7 for i, ax in enumerate(axs.flat):
#       8     # Plot a histogram for each column in the grid
# ----> 9     ax.hist(new_df[columns_to_plot[i]], bins=30, edgecolor='black')
#      10     ax.set_title(f'Histogram of {columns_to_plot[i]}')
#      11     ax.set_xlabel(columns_to_plot[i])
#
# IndexError: list index out of range

# %%
import seaborn as sns
corr_matrix = new_df.corr()
plt.figure(figsize=(12, 10))

# Plot the heatmap
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', square=True, linewidths=0.5)
#sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', square=True, linewidths=0.5, annot_kws={"size": 10})

# Set the title
plt.title('Correlation Heatmap of Spotify Dataset')

# Display the heatmap
plt.show()

# %%
new_df.corr()
# Out:
#                   popularity  duration_ms  explicit  danceability    energy  \
# popularity          1.000000    -0.024684  0.052096      0.056820 -0.007606
# duration_ms        -0.024684     1.000000 -0.087598     -0.070383  0.099916
# explicit            0.052096    -0.087598  1.000000      0.111894  0.096675
# danceability        0.056820    -0.070383  0.111894      1.000000  0.121554
# energy             -0.007606     0.099916  0.096675      0.121554  1.000000
# key                -0.001780     0.016965  0.002175      0.032744  0.043356
# loudness            0.079101     0.023134  0.111678      0.192047  0.787947
# mode               -0.003746    -0.044636 -0.033395     -0.065377 -0.076626
# speechiness        -0.061699    -0.099113  0.314587      0.105569  0.139827
# acousticness       -0.023186    -0.155230 -0.086595     -0.159881 -0.734179
# instrumentalness   -0.142835     0.105710 -0.105804     -0.179800 -0.182730
# ...
